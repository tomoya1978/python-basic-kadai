# %%
var = 6
if var % 3 == 0:
   print("Fizz")
else:
    print(var)
# Out:
# Fizz

# %%
var = 10
if var % 10 == 0:
   print("Buzz")
else:
    print(var)

# %%
var = 15
if var % 3 == 0 and var % 5 == 0:
    print("FizzBuzz")
else:
    print(var)
